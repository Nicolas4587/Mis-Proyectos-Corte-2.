# %% [markdown]
# Informe de Laboratorio
#
# ![logo.png](data:image/png;base64,...)
# *   Laboratorio de Mecanica
# *Densidad Experimental
# *Nicolas Gomez Amaya, U00158754
# * Juan David Urbina Almeyda, U00156031
# * Daniela Olago Jurado, U00154657
# * Mauricio Figueroa Narvaez, U00156567
# * Revisado Por
# * Prof. Juan Carlos Quijano
# * 10 de noviembre de 2022

# %% [markdown]
# ##Objetivo:
# El objetivo de este experimento es calcular y comprobar la densidad de varios objetos,
# como tambien el volumen y su masa; Tambien lo comprobaremos con su analisis de grafica
# para ver como quedaron los resultados.

# %% [markdown]
# ##Marco Teorico
# ##2.1. Densidad-Concepto e historia
# La densidad es la relaci ́on que hay entre la masa de un cuerpo y el volumen que esta
# misma ocupa es decir , este concepto hace referencia que tan juntos est ́an los  ́atomos de un
# objeto, entre m ́as unidos est ́en es m ́as denso. Haciendo referencia a algo de la historia de este
# concepto (no se tiene la certeza de esta historia) se remonta a 250 a ̃nos A.C , Arqu ́ımedes
# (considerado el padre de la hidrost ́atica) ten ́ıa una tarea indicada por el rey de Siracusa
# que era encontrar la relaci ́on de la masa y el volumen del oro que el rey hab ́ıa entregado al
# orfebre para fabricar su corona; Arqu ́ımedes en medio de su dilema un d ́ıa que entro a su
# ba ̃nera, al ver que a medida que entraba su cuerpo sal ́ıa el agua dedujo que el volumen del
# agua desplazada el mismo del volumen de su cuerpo cuando se sumerg ́ıa en ella.
# ##2.2. volumen de objetos
# Se puede mencionar que algunas de las nociones de volumen son las siguientes: magnitud
# tridimensional, volumen como capacidad, volumen como lugar que ocupa un objeto en el
# espacio o una combinaci ́on de ambas nociones. Seg ́un Kerslake (1976) la palabra volumen
# puede ser usada con dos significados: 1) Volumen Interno como capacidad y Volumen Externo
# como cantidad de espacio ocupado. La medici ́on del volumen se da en o tambi ́en generalmente
# se utiliza en Litro ( L). Seg ́un el estado en que se encuentre el elemento se usan diferentes
# herramientas de medici ́on. En el caso de los l ́ıquidos se utiliza: probeta, vaso precipitado.

# %% [markdown]
# 3. Datos:
#
# ![tb.png](data:image/png;base64,...)
#
# Tabla de Densidad Experimental

# %% [markdown]
# Grafica de Densidad experimental:
#
# ![Imagen1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##Analisis de Resultados
# En el experimento se pudo comprobar la relaci ́on directamente proporcional del Volumen
# con la Masa, variables, que operadas en cociente, permiten conocer la Densidad.
# As ́ı mismo, mediante el an ́alisis de la gr ́afica, se evidencia la tendencia lineal de la interacci ́on
# V vs M, hallando un coeficiente de correlaci ́on de 0.96 aproximadamente, es decir, un muy
# buen sincretismo en los datos.

# %% [markdown]
# ![porerror.png](data:image/png;base64,...)

# %% [markdown]
# ##Conclusiones
# ##5.1.
# Gracias al experimento realizado pudimos encontrar una manera de calcular la densidad
# de un material, esta manera es hallando el volumen de una figura junto a su masa y calcular
# su relaci ́on.
# ##5.2.
# Este experimento nos demuestra que, en un cuerpo, la masa es lineal al volumen. Es decir
# que si el volumen aumenta o disminuye la masa har ́a lo mismo.
# ##5.3.
# Con el experimento podemos concluir que, aunque se realicen algunos peque ̃nos errores
# de medici ́on, los caculos de la densidad siempre deben estar cercanos a la l ́ınea de densidad
# promedio, como se demuestra en el grafico.

# %% [markdown]
# ##Bibliografia:
#
# [1] Garcıa Garcıa, H. (2016). Uso de los laboratorios virtuales para la ense ̃nanza-aprendizaje
# del concepto materia y sus propiedades en estudiantes de grado noveno.
#
# [2] Saucedo, Gladis (2009). Hacia la construcci ́on del concepto de volumen. En Zapico, Ire-
# ne; Tajeyan, Silvia (Eds.), ACTAS DE LA VII CONFERENCIA ARGENTINA DE EDU-
# CACI  ́ON MATEM  ́ATICA (pp. 1-8). Buenos Aires, Argentina: SOAREM.
#
# [3] Garc ́ıa Garc ́ıa, H. (2016). Uso de los laboratorios virtuales para la ense ̃nanza-aprendizaje
# del concepto materia y sus propiedades en estudiantes de grado noveno.
#
# [4] https://www.tplaboratorioquimico.com/quimica-general/las-propiedades-de-la-
# materia/que-es- el-volumen.html
